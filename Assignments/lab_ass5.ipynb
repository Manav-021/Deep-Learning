# %%
import numpy as np
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data"
columns = ["Sex","Length","Diameter","Height","Whole_weight",
           "Shucked_weight","Viscera_weight","Shell_weight","Rings"]

df = pd.read_csv(url, header=None, names=columns)

print("\nFirst 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
y = df["Rings"].values.reshape(-1,1) + 1.5
X = df[["Length","Diameter","Shell_weight"]].values

# %%
N = X.shape[0]
split = int(0.8 * N)

X_train = X[:split]
X_test = X[split:]
y_train = y[:split]
y_test = y[split:]

# %%
mean = X_train.mean(axis=0)
std = X_train.std(axis=0)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
def forward(X, w, b):
    y_hat = np.dot(X, w) + b
    return y_hat

# %%
def mse(y, y_hat):
    return np.mean((y - y_hat) ** 2)

# %%
def mae(y, y_hat):
    return np.mean(np.abs(y - y_hat))

# %%
def grad_w(X, y, y_hat):
    N = X.shape[0]
    return (-2/N) * np.dot(X.T, (y - y_hat))

# %%
def grad_b(y, y_hat):
    N = y.shape[0]
    return (-2/N) * np.sum(y - y_hat)

# %%
d = X_train.shape[1]
w = np.random.randn(d,1) * 0.01
b = 0.0

lr = 0.01
epochs = 200

# %%
for epoch in range(epochs):
    y_hat = forward(X_train, w, b)
    loss = mse(y_train, y_hat)
    dW = grad_w(X_train, y_train, y_hat)
    db = grad_b(y_train, y_hat)
    w = w - lr * dW
    b = b - lr * db
    if epoch % 20 == 0:
        print(f"Epoch {epoch:03d} | Loss: {loss:.6f}")
# Out:
# Epoch 000 | Loss: 144.184416
# Epoch 020 | Loss: 66.735525
# Epoch 040 | Loss: 33.453433
# Epoch 060 | Loss: 18.720690
# Epoch 080 | Loss: 12.149021
# Epoch 100 | Loss: 9.206072
# Epoch 120 | Loss: 7.880918
# Epoch 140 | Loss: 7.278031
# Epoch 160 | Loss: 6.998228
# Epoch 180 | Loss: 6.863484

# %%
y_test_hat = forward(X_test, w, b)

test_mse = mse(y_test, y_test_hat)
test_mae = mae(y_test, y_test_hat)

print(f"Test MSE : {test_mse:.6f}")
print(f"Test MAE : {test_mae:.6f}")


for i in range(5):
    true_val = y_test[i][0]
    pred_val = y_test_hat[i][0]
    error = abs(true_val - pred_val)
    print(f"Sample {i+1}:")
    print(f"  True Age      : {true_val:.3f}")
    print(f"  Predicted Age : {pred_val:.3f}")
    print(f"  Absolute Error: {error:.3f}\n")
# Out:
# Test MSE : 4.910706
# Test MAE : 1.657385
# Sample 1:
#   True Age      : 13.500
#   Predicted Age : 10.681
#   Absolute Error: 2.819
#
# Sample 2:
#   True Age      : 15.500
#   Predicted Age : 9.567
#   Absolute Error: 5.933
#
# Sample 3:
#   True Age      : 14.500
#   Predicted Age : 10.013
#   Absolute Error: 4.487
#
# Sample 4:
#   True Age      : 14.500
#   Predicted Age : 10.891
#   Absolute Error: 3.609
#
# Sample 5:
#   True Age      : 13.500
#   Predicted Age : 11.016
#   Absolute Error: 2.484
